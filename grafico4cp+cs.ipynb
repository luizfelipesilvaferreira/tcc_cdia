# %% [markdown]
# # CLUSTERIZAÇÃO VARIÁVEIS SINTÉTICAS DE NÍVEL DE DESENVOLVIMENTO DO MUNICÍPIO
#
# CNAE_FISCAL_PRINCIPAL - MUNICÍPIO - CONTAGEM_CP_ANO_MUN

# %%
import pandas as pd
df = pd.read_csv('df_final_cp+cs.csv')
df
# Out:
#           DATA_DE_INÍCIO_ATIVIDADE  CNAE_FISCAL_PRINCIPAL  \
# 0                             2023                4644301
# 1                             2023                4637104
# 2                             2023                4647801
# 3                             2023                4647801
# 4                             2023                4647801
# ...                            ...                    ...
# 85176660                      1903                9430800
# 85176661                      1901                9430800
# 85176662                      1901                9430800
# 85176663                      1901                6912500
# 85176664                      1891                1321900
#
#           CNAE_FISCAL_SECUNDÁRIA  MUNICÍPIO
# 0                        4645101       7885
# 1                        4691500       1569
# 2                        4641902       1219
# 3                        4635401       1219
# 4                        4623109       1219
# ...                          ...        ...
# 85176660                 9499500        921
# 85176661                 9499500       8927
# 85176662                 9493600       8927
# 85176663                 9609299       6645
# 85176664                 7490104       4675
#
# [85176665 rows x 4 columns]

# %%
# Primeiro, criamos um DataFrame temporário com a contagem de 'CNAE_FISCAL_PRINCIPAL' e 'CNAE_FISCAL_SECUNDÁRIA' por 'ANO' e 'MUNICÍPIO'
df_contagem_por_municipio = df.groupby(['DATA_DE_INÍCIO_ATIVIDADE', 'MUNICÍPIO'])[['CNAE_FISCAL_PRINCIPAL', 'CNAE_FISCAL_SECUNDÁRIA']].count().reset_index()
df_contagem_por_municipio.rename(columns={'CNAE_FISCAL_PRINCIPAL': 'CONTAGEM_PRINCIPAL', 'CNAE_FISCAL_SECUNDÁRIA': 'CONTAGEM_SECUNDÁRIA'}, inplace=True)

# Calculamos a soma das contagens principal e secundária para obter a contagem total
df_contagem_por_municipio['CONTAGEM_CP+CS_ANO_MUN'] = df_contagem_por_municipio['CONTAGEM_PRINCIPAL'] + df_contagem_por_municipio['CONTAGEM_SECUNDÁRIA']

# Em seguida, fundimos os dados de contagem ao DataFrame original usando 'ANO' e 'MUNICÍPIO' como chaves de junção
df = df.merge(df_contagem_por_municipio[['DATA_DE_INÍCIO_ATIVIDADE', 'MUNICÍPIO', 'CONTAGEM_CP+CS_ANO_MUN']], on=['DATA_DE_INÍCIO_ATIVIDADE', 'MUNICÍPIO'], how='left')
df
# Out:
#           DATA_DE_INÍCIO_ATIVIDADE  CNAE_FISCAL_PRINCIPAL  \
# 0                             2023                4644301
# 1                             2023                4637104
# 2                             2023                4647801
# 3                             2023                4647801
# 4                             2023                4647801
# ...                            ...                    ...
# 85176660                      1903                9430800
# 85176661                      1901                9430800
# 85176662                      1901                9430800
# 85176663                      1901                6912500
# 85176664                      1891                1321900
#
#           CNAE_FISCAL_SECUNDÁRIA  MUNICÍPIO  CONTAGEM_CP+CS_ANO_MUN
# 0                        4645101       7885                   11412
# 1                        4691500       1569                    2458
# 2                        4641902       1219                   25480
# 3                        4635401       1219                   25480
# 4                        4623109       1219                   25480
# ...                          ...        ...                     ...
# 85176660                 9499500        921                       4
# 85176661                 9499500       8927                       4
# 85176662                 9493600       8927                       4
# 85176663                 9609299       6645                       2
# 85176664                 7490104       4675                       2
#
# [85176665 rows x 5 columns]

# %%
# EXCLUINDO AS INFORMAÇÕES NÃO NECESSÁRIAS AO MODELO:
df = df.drop(['DATA_DE_INÍCIO_ATIVIDADE'], axis=1)
df
# Out:
#           CNAE_FISCAL_PRINCIPAL  CNAE_FISCAL_SECUNDÁRIA  MUNICÍPIO  \
# 0                       4644301                 4645101       7885
# 1                       4637104                 4691500       1569
# 2                       4647801                 4641902       1219
# 3                       4647801                 4635401       1219
# 4                       4647801                 4623109       1219
# ...                         ...                     ...        ...
# 85176660                9430800                 9499500        921
# 85176661                9430800                 9499500       8927
# 85176662                9430800                 9493600       8927
# 85176663                6912500                 9609299       6645
# 85176664                1321900                 7490104       4675
#
#           CONTAGEM_CP+CS_ANO_MUN
# 0                          11412
# 1                           2458
# 2                          25480
# 3                          25480
# 4                          25480
# ...                          ...
# 85176660                       4
# 85176661                       4
# 85176662                       4
# 85176663                       2
# 85176664                       2
#
# [85176665 rows x 4 columns]

# %%
dados_cluster = df[['CNAE_FISCAL_PRINCIPAL', 'CNAE_FISCAL_SECUNDÁRIA', 'MUNICÍPIO', 'CONTAGEM_CP+CS_ANO_MUN']]
dados_cluster
# Out:
#           CNAE_FISCAL_PRINCIPAL  CNAE_FISCAL_SECUNDÁRIA  MUNICÍPIO  \
# 0                       4644301                 4645101       7885
# 1                       4637104                 4691500       1569
# 2                       4647801                 4641902       1219
# 3                       4647801                 4635401       1219
# 4                       4647801                 4623109       1219
# ...                         ...                     ...        ...
# 85176660                9430800                 9499500        921
# 85176661                9430800                 9499500       8927
# 85176662                9430800                 9493600       8927
# 85176663                6912500                 9609299       6645
# 85176664                1321900                 7490104       4675
#
#           CONTAGEM_CP+CS_ANO_MUN
# 0                          11412
# 1                           2458
# 2                          25480
# 3                          25480
# 4                          25480
# ...                          ...
# 85176660                       4
# 85176661                       4
# 85176662                       4
# 85176663                       2
# 85176664                       2
#
# [85176665 rows x 4 columns]

# %%
# Realize a amostragem aleatória simples com 0,001% dos dados
dados_cluster = dados_cluster.sample(frac=0.0001, random_state=42)
dados_cluster
# Out:
#           CNAE_FISCAL_PRINCIPAL  CNAE_FISCAL_SECUNDÁRIA  MUNICÍPIO  \
# 13371777                4781400                 4783102       9701
# 17844177                1821100                 7420004       5403
# 16910876                8230001                 8599699       6377
# 49398932                8130300                 3299099       2913
# 23025343                5620104                 7911200       3215
# ...                         ...                     ...        ...
# 21782925                4744099                 2511000       7735
# 68496831                 121101                  134200       6225
# 60948296                4929901                 4924800       6001
# 56463131                6203100                 6209100       7107
# 35131715                8211300                 8111700       1116
#
#           CONTAGEM_CP+CS_ANO_MUN
# 13371777                  371228
# 17844177                   83878
# 16910876                   28248
# 49398932                    2642
# 23025343                     340
# ...                          ...
# 21782925                    2454
# 68496831                     276
# 60948296                  233406
# 56463131                  518942
# 35131715                    9450
#
# [8518 rows x 4 columns]

# %%
# transformações necessárias para aplicação do algoritmo
# Converter as colunas "MUNICÍPIO" e "CNAE_FISCAL_PRINCIPAL" em string
dados_cluster["MUNICÍPIO"] = dados_cluster["MUNICÍPIO"].astype(str)
dados_cluster["CNAE_FISCAL_PRINCIPAL"] = dados_cluster["CNAE_FISCAL_PRINCIPAL"].astype(str)
dados_cluster["CNAE_FISCAL_SECUNDÁRIA"] = dados_cluster["CNAE_FISCAL_SECUNDÁRIA"].astype(str)

# Agrupar o DataFrame pelos campos desejados
grupo = dados_cluster.groupby(["CONTAGEM_CP+CS_ANO_MUN", "MUNICÍPIO", "CNAE_FISCAL_PRINCIPAL", "CNAE_FISCAL_SECUNDÁRIA"]).size().reset_index(name="Contagem")

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
dados_cluster_scaled = scaler.fit_transform(grupo)

pca = PCA(n_components=2)  # k é o número de componentes principais desejados
X = pca.fit_transform(dados_cluster_scaled)

componentes_principais = pca.components_
variancia_explicada = pca.explained_variance_ratio_

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# Aplicando o DBSCAN
eps = 0.3  # Parâmetro de distância máxima entre os pontos do mesmo cluster
min_samples = 5  # Número mínimo de pontos para formar um cluster
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
labels = dbscan.fit_predict(X)

# Obtendo a quantidade de clusters encontrados
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print(f"Número de clusters encontrados: {n_clusters}")

# Criando um gráfico colorido dos clusters
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Ruído é exibido em preto
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask]
    plt.scatter(xy[:, 0], xy[:, 1], c=[col], marker='o', s=0.5)

plt.title('DBSCAN: Número de clusters encontrados {}'.format(n_clusters))

# Centralizar o gráfico na origem
plt.axis('equal')
plt.xlim(-3, 3)
plt.ylim(-3, 3)

plt.show()
# Out:
# Número de clusters encontrados: 10

# %% [markdown]
# # CLUSTERIZAÇÃO VARIÁVEIS SINTÉTICAS DE NÍVEL DE DESENVOLVIMENTO DO MUNICÍPIO
#
# CNAE_FISCAL_PRINCIPAL - MUNICÍPIO - CONTAGEM_CP_ANO_MUN
#
# Tendo em vista a utilização de apenas 0,001% dos dados devido às limitações de poder computacional existentes, o gráfico apresentado possui distribuição esparça e uniforme próxima ao eixo "y". Os 3 clusters encontrados não apresentaram resultados conclusivos ao formato dos dados. O posicionamento dos dados indica uma curva de crescimento acentuado próximo ao eixo, o que pode indicar que se comparado ao primeiro gráfico, os dados .
